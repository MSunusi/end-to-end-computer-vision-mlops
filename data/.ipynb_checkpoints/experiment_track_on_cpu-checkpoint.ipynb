# %%
#install the libraries
from ultralytics import YOLO
import mlflow

# %%
# -------------------------------
# MLflow Setup
# -------------------------------
mlflow.set_tracking_uri("http://127.0.0.1:5000")
mlflow.set_experiment("YOLO8nn-Simple-Experiment")

# ========================================
# MODEL 1: YOLOv8 Nano
# ========================================
# Parameters for this model
model_file = "yolov8n.pt"
epochs = 1
batch = 4
learning_rate = 0.01

# Start MLflow run for this model
with mlflow.start_run(run_name="YOLOv8-Nano"):
    print(f"Training {model_file}...")
    #tag developer name
    mlflow.set_tag("developer", "sunusi")
    # Log hyperparameters
    mlflow.log_param("model_file", model_file)
    mlflow.log_param("epochs", epochs)
    mlflow.log_param("batch", batch)
    mlflow.log_param("learning_rate", learning_rate)
    
    # Initialize and train
    model = YOLO(model_file)
    results = model.train(
        data="sesame-plant-detection/data.yaml",   
        epochs=epochs,
        batch=batch,
        lr0=learning_rate,
        device="cpu"
    )
    
    # Log metrics
        mlflow.log_metric("mAP50", results.metrics.get("mAP50", 0))
    mlflow.log_metric("precision", results.metrics.get("precision", 0))
    mlflow.log_metric("recall", results.metrics.get("recall", 0))
    
    # Log model
    mlflow.pytorch.log_model(model.model, "yolo8-nano-model")
    print("YOLO888 Nano logged successfully!")
# Out:
# Training yolov8n.pt...
# New https://pypi.org/project/ultralytics/8.4.11 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.10 🚀 Python-3.12.3 torch-2.10.0+cu128 CPU (Intel Core i7-3517U 1.90GHz)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=4, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=sesame-plant-detection/data.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=1, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=train6, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/home/user/end-to-end-computer-vision-mlops/data/runs/detect/train6, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751507  ultralytics.nn.modules.head.Detect           [1, 16, None, [64, 128, 256]]
# [W204 10:44:07.316751609 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:07.334027879 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:07.336073751 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:07.338241459 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:07.349748816 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:07.354283549 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:07.356570120 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:07.363722838 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:07.381615392 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:07.387064113 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:07.437386468 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:07.439805873 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:07.449345772 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:07.451280888 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:07.472323110 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:07.482492637 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:07.488142308 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:07.497117539 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:07.525167877 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:07.683538603 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:07.730581136 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:07.750927138 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:07.805870005 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:07.840452658 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:08.362047013 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:08.379818455 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:08.429785420 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:08.455707193 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:08.506685832 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:08.536831313 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:08.548219791 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:08.572818103 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:08.587086691 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:08.613036247 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:08.640973573 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:08.677576345 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:08.716657388 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:08.733715248 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:08.744092161 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:08.746456632 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:08.763640544 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:08.786763776 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:08.808253571 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:08.827842582 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:08.841763192 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:08.874550950 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:08.881844531 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:08.903588888 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:08.923602503 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:08.932777308 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:08.953170084 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:08.960348775 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:08.962593950 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:08.970321029 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:08.982531565 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:08.985466434 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:08.002782916 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:08.004353010 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:08.005246827 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:08.007390498 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:08.008365000 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:08.011529636 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:08.012438006 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:08.013988963 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:08.014786508 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:08.015667100 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:08.016483698 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:08.024602576 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:08.025754890 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:08.028171892 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:08.032163464 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:08.053707658 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:08.062494237 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:09.082403253 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:09.095378674 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:09.096705823 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:09.107832760 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:09.117265833 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:09.119698521 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:09.137485466 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:09.159562425 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:09.162475483 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:09.171783012 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:09.185272156 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:09.186626220 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:09.199786339 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# Model summary: 130 layers, 3,011,043 parameters, 3,011,027 gradients, 8.2 GFLOPs
# [W204 10:44:09.224667210 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 10:44:09.266213428 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# train: Fast image access ✅ (ping: 0.1±0.0 ms, read: 17.6±18.8 MB/s, size: 123.1 KB)
# train: Scanning /home/user/end-to-end-computer-vision-mlops/data/sesame-plant-detection/train/labels.cache... 262 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 262/262 11.7Mit/s 0.0s
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 72.3±28.9 MB/s, size: 129.0 KB)
# val: Scanning /home/user/end-to-end-computer-vision-mlops/data/sesame-plant-detection/valid/labels.cache... 31 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 31/31 802.6Kit/s 0.0s
# Plotting labels to /home/user/end-to-end-computer-vision-mlops/data/runs/detect/train6/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# MLflow: logging run_id(72720f63d51145e488f6374bceafa361) to http://127.0.0.1:5000
# MLflow: disable with 'yolo settings mlflow=False'
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to /home/user/end-to-end-computer-vision-mlops/data/runs/detect/train6
# Starting training for 1 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         1/1         0G      1.521      2.135      1.452         40        640: 100% ━━━━━━━━━━━━ 66/66 27.6s/it 30:2025.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 21.0s/it 1:24<28.4s
#                    all         31        511      0.686      0.671      0.676      0.374
#
# 1 epochs completed in 0.534 hours.
# Optimizer stripped from /home/user/end-to-end-computer-vision-mlops/data/runs/detect/train6/weights/last.pt, 6.2MB
# Optimizer stripped from /home/user/end-to-end-computer-vision-mlops/data/runs/detect/train6/weights/best.pt, 6.2MB
#
# Validating /home/user/end-to-end-computer-vision-mlops/data/runs/detect/train6/weights/best.pt...
# Ultralytics 8.4.10 🚀 Python-3.12.3 torch-2.10.0+cu128 CPU (Intel Core i7-3517U 1.90GHz)
# [W204 11:16:25.625870108 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:16:25.702454529 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:16:25.708485918 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:16:25.716756976 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:16:25.758714612 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:16:25.793123531 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:16:25.806849992 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:16:25.835510886 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:16:25.876326430 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:16:25.912106713 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:16:25.942911214 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:16:25.023990578 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:16:25.047955807 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:16:26.075313310 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:16:26.099452727 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:16:26.110319290 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:16:26.117212138 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:16:26.128630502 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:16:26.136968605 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:16:26.152121992 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:16:26.154231256 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:16:26.165556881 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:16:26.177959896 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:16:26.205649158 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:16:26.249250698 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:16:26.262808865 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:16:26.340946110 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:16:26.366471318 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:16:26.376164805 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:16:26.392678401 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:16:26.409728722 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:16:26.426826090 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:16:26.461090337 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:16:26.522165634 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:16:26.642951284 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:16:26.653257999 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:16:26.683644025 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:16:26.691378312 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:16:26.725708838 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:16:26.739281683 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:16:26.748164356 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:16:26.774858557 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:16:26.810181132 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:16:26.827928622 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:16:26.878526117 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:16:26.898088502 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:16:26.921189551 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:16:26.954812767 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:16:26.990590544 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:16:26.006269516 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:16:26.033670783 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:16:26.053652483 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:16:26.073519410 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:16:27.125405473 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:16:27.149865263 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:16:27.194573099 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:16:27.328542661 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:16:27.335179365 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# Model summary (fused): 73 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
# [W204 11:16:27.345588838 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:16:27.356617156 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:16:27.365404188 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:16:27.376729181 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:16:27.387771612 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:16:27.405295913 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 19.0s/it 1:1629.9s
#                    all         31        511       0.69      0.675      0.677      0.374
# Speed: 15.5ms preprocess, 2286.8ms inference, 0.0ms loss, 38.3ms postprocess per image
# Results saved to /home/user/end-to-end-computer-vision-mlops/data/runs/detect/train6
# 🏃 View run YOLOv8-Nano at: http://127.0.0.1:5000/#/experiments/4/runs/72720f63d51145e488f6374bceafa361
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/4
# MLflow: results logged to http://127.0.0.1:5000
# MLflow: disable with 'yolo settings mlflow=False'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 38
#      29 results = model.train(
#      30     data="sesame-plant-detection/data.yaml",
#      31     epochs=epochs,
#    (...)     34     device="cpu"
#      35 )
#      37 # Log metrics
# ---> 38 mlflow.log_metric("mAP50", results.metrics.get("mAP50", 0))
#      39 mlflow.log_metric("precision", results.metrics.get("precision", 0))
#      40 mlflow.log_metric("recall", results.metrics.get("recall", 0))
#
# File ~/experiment-track/lib/python3.12/site-packages/ultralytics/utils/__init__.py:279, in SimpleClass.__getattr__(self, attr)
#     277 """Provide a custom attribute access error message with helpful information."""
#     278 name = self.__class__.__name__
# --> 279 raise AttributeError(f"'{name}' object has no attribute '{attr}'. See valid attributes below.\n{self.__doc__}")
#
# AttributeError: 'DetMetrics' object has no attribute 'metrics'. See valid attributes below.
# Utility class for computing detection metrics such as precision, recall, and mean average precision (mAP).
#
#     Attributes:
#         names (dict[int, str]): A dictionary of class names.
#         box (Metric): An instance of the Metric class for storing detection results.
#         speed (dict[str, float]): A dictionary for storing execution times of different parts of the detection process.
#         task (str): The task type, set to 'detect'.
#         stats (dict[str, list]): A dictionary containing lists for true positives, confidence scores, predicted classes,
#             target classes, and target images.
#         nt_per_class: Number of targets per class.
#         nt_per_image: Number of targets per image.
#
#     Methods:
#         update_stats: Update statistics by appending new values to existing stat collections.
#         process: Process predicted results for object detection and update metrics.
#         clear_stats: Clear the stored statistics.
#         keys: Return a list of keys for accessing specific metrics.
#         mean_results: Calculate mean of detected objects & return precision, recall, mAP50, and mAP50-95.
#         class_result: Return the result of evaluating the performance of an object detection model on a specific class.
#         maps: Return mean Average Precision (mAP) scores per class.
#         fitness: Return the fitness of box object.
#         ap_class_index: Return the average precision index per class.
#         results_dict: Return dictionary of computed performance metrics and statistics.
#         curves: Return a list of curves for accessing specific metrics curves.
#         curves_results: Return a list of computed performance metrics and statistics.
#         summary: Generate a summarized representation of per-class detection metrics as a list of dictionaries.

# %%
#correct logs  YOLOv8 detection metrics
mlflow.log_metric("mAP50", results.box.map50)
mlflow.log_metric("mAP50-95", results.box.map)
mlflow.log_metric("precision", results.box.mp)
mlflow.log_metric("recall", results.box.mr)

# %%
# =========================================
# YOLOv8 + MLflow Beginner Step-by-Step
# =========================================

# Install dependencies if needed
# !pip install ultralytics mlflow[extras,pytorch]

import mlflow
from ultralytics import YOLO

# -------------------------------
# MLflow Setup
# -------------------------------
mlflow.set_tracking_uri("http://127.0.0.1:5000")
mlflow.set_experiment("YOLOv8-Simple-Experiment")

# ========================================
# MODEL 1: YOLOv8 Nano
# ========================================
# Parameters for this model
model_file = "yolov8n.pt"
epochs = 3
batch = 8
learning_rate = 0.01

# Start MLflow run for this model
with mlflow.start_run(run_name="YOLOv8-Nano"):
    print(f"Training {model_file}...")
    
    # Log hyperparameters
    mlflow.log_param("model_file", model_file)
    mlflow.log_param("epochs", epochs)
    mlflow.log_param("batch", batch)
    mlflow.log_param("learning_rate", learning_rate)
    
    # Initialize and train
    model = YOLO(model_file)
    results = model.train(
        data="dataset.yaml",  # replace with your dataset YAML
        epochs=epochs,
        batch=batch,
        lr0=learning_rate
    )
    
    # Log metrics
    mlflow.log_metric("mAP50", results.metrics.get("mAP50", 0))
    mlflow.log_metric("precision", results.metrics.get("precision", 0))
    mlflow.log_metric("recall", results.metrics.get("recall", 0))
    
    # Log model
    mlflow.pytorch.log_model(model.model, "yolov8-nano-model")
    print("YOLOv8 Nano logged successfully!")

# ========================================
# MODEL 2: YOLOv8 Large
# ========================================
model_file = "yolov8l.pt"
epochs = 5
batch = 4
learning_rate = 0.001

with mlflow.start_run(run_name="YOLOv8-Large"):
    print(f"Training {model_file}...")
    
    mlflow.log_param("model_file", model_file)
    mlflow.log_param("epochs", epochs)
    mlflow.log_param("batch", batch)
    mlflow.log_param("learning_rate", learning_rate)
    
    model = YOLO(model_file)
    results = model.train(
        data="dataset.yaml",
        epochs=epochs,
        batch=batch,
        lr0=learning_rate
    )
    
    mlflow.log_metric("mAP50", results.metrics.get("mAP50", 0))
    mlflow.log_metric("precision", results.metrics.get("precision", 0))
    mlflow.log_metric("recall", results.metrics.get("recall", 0))
    
    mlflow.pytorch.log_model(model.model, "yolov8-large-model")
    print("YOLOv8 Large logged successfully!")

# ========================================
# MODEL 3: YOLOv8 Nano6
# ========================================
model_file = "yolov8n6.pt"
epochs = 4
batch = 6
learning_rate = 0.005

with mlflow.start_run(run_name="YOLOv8-Nano6"):
    print(f"Training {model_file}...")
    
    mlflow.log_param("model_file", model_file)
    mlflow.log_param("epochs", epochs)
    mlflow.log_param("batch", batch)
    mlflow.log_param("learning_rate", learning_rate)
    
    model = YOLO(model_file)
    results = model.train(
        data="dataset.yaml",
        epochs=epochs,
        batch=batch,
        lr0=learning_rate
    )
    
    mlflow.log_metric("mAP50", results.metrics.get("mAP50", 0))
    mlflow.log_metric("precision", results.metrics.get("precision", 0))
    mlflow.log_metric("recall", results.metrics.get("recall", 0))
    
    mlflow.pytorch.log_model(model.model, "yolov8-nano6-model")
    print("YOLOv8 Nano6 logged successfully!")

print("All three models trained and logged separately!")
