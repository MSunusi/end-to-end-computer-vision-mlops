# %%
#install the libraries
from ultralytics import YOLO
import mlflow

# %%
# -------------------------------
# MLflow Setup
# -------------------------------
mlflow.set_tracking_uri("http://127.0.0.1:5000")
mlflow.set_experiment("YOLO8nn-Simple-Experiment")

# ========================================
# MODEL 1: YOLOv8 Nano
# ========================================
# Parameters for this model
model_file = "yolov8n.pt"
epochs = 1
batch = 4
learning_rate = 0.01

# Start MLflow run for this model
with mlflow.start_run(run_name="YOLOv8-Nano"):
    print(f"Training {model_file}...")
    #tag developer name
    mlflow.set_tag("developer", "sunusi")
    # Log hyperparameters
    mlflow.log_param("model_file", model_file)
    mlflow.log_param("epochs", epochs)
    mlflow.log_param("batch", batch)
    mlflow.log_param("learning_rate", learning_rate)
    
    # Initialize and train
    model = YOLO(model_file)
    results = model.train(
        data="sesame-plant-detection/data.yaml",   
        epochs=epochs,
        batch=batch,
        lr0=learning_rate,
        device="cpu"
    )
    
    # Log metrics
    mlflow.log_metric("mAP50", results.box.map50)
    mlflow.log_metric("mAP50-95", results.box.map)
    mlflow.log_metric("precision", results.box.mp)
    mlflow.log_metric("recall", results.box.mr)
# Out:
# Training yolov8n.pt...
# New https://pypi.org/project/ultralytics/8.4.11 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.10 🚀 Python-3.12.3 torch-2.10.0+cu128 CPU (Intel Core i7-3517U 1.90GHz)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=4, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=sesame-plant-detection/data.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=1, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=train7, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/home/user/end-to-end-computer-vision-mlops/data/runs/detect/train7, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751507  ultralytics.nn.modules.head.Detect           [1, 16, None, [64, 128, 256]]
# [W204 11:48:49.426902118 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:49.474262765 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:49.525792432 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:49.578344065 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:49.742633722 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:49.760156058 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:49.783594952 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:49.826999190 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:49.954416490 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:49.984420792 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:50.334901025 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:50.375118556 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:50.516078068 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:50.551894314 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:50.881448723 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:50.940559420 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:50.950269203 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:50.002820923 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:50.027760528 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:51.259814193 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:51.311763821 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:51.319750808 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:51.374513008 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:51.417890930 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:52.778575199 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:52.832084504 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:52.874491766 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:52.897493249 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:52.925842743 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:52.950890321 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:52.966561192 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:52.017622997 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:52.072179945 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:53.111943666 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:53.241613870 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:53.321460020 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:53.350080259 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:53.417460992 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:53.430841754 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:53.439471721 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:53.451258117 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:53.463577946 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:53.498937514 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:53.513710080 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:53.524923644 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:53.554841645 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:53.576152686 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:53.604135784 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:53.661730131 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:53.674714755 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:53.726361429 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:53.737343551 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:53.744818263 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:53.777699808 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:53.804681342 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:53.823523139 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:53.827856041 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:53.836326559 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:53.848244797 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:53.904458506 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:53.924310767 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:53.946658015 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:53.972372887 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:53.990906274 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:53.038567766 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:54.121728992 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:54.147776866 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:54.213507477 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:54.272591604 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:54.313145417 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:54.389707170 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:54.464351920 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:54.484676987 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:54.514517850 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:54.537817285 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:54.552871736 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:54.564691036 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:54.596901753 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:54.656175668 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:54.751863495 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:54.856268290 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:54.925139253 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:54.983555369 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:55.133867741 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:55.183598980 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:55.255507549 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 11:48:55.320653638 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# Model summary: 130 layers, 3,011,043 parameters, 3,011,027 gradients, 8.2 GFLOPs
# [W204 11:48:55.467792968 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# train: Fast image access ✅ (ping: 0.1±0.0 ms, read: 27.1±15.7 MB/s, size: 123.1 KB)
# train: Scanning /home/user/end-to-end-computer-vision-mlops/data/sesame-plant-detection/train/labels.cache... 262 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 262/262 195.4Kit/s 0.0s
# val: Fast image access ✅ (ping: 0.1±0.0 ms, read: 47.9±17.6 MB/s, size: 129.0 KB)
# val: Scanning /home/user/end-to-end-computer-vision-mlops/data/sesame-plant-detection/valid/labels.cache... 31 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 31/31 1.4Mit/s 0.0s
# Plotting labels to /home/user/end-to-end-computer-vision-mlops/data/runs/detect/train7/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# MLflow: logging run_id(045774a3fc5d4fbdbb21f97892ef29fe) to http://127.0.0.1:5000
# MLflow: disable with 'yolo settings mlflow=False'
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to /home/user/end-to-end-computer-vision-mlops/data/runs/detect/train7
# Starting training for 1 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         1/1         0G      1.521      2.135      1.452         40        640: 100% ━━━━━━━━━━━━ 66/66 24.0s/it 26:2516.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 14.5s/it 57.9s18.7s
#                    all         31        511      0.686      0.671      0.676      0.374
#
# 1 epochs completed in 0.461 hours.
# Optimizer stripped from /home/user/end-to-end-computer-vision-mlops/data/runs/detect/train7/weights/last.pt, 6.2MB
# Optimizer stripped from /home/user/end-to-end-computer-vision-mlops/data/runs/detect/train7/weights/best.pt, 6.2MB
#
# Validating /home/user/end-to-end-computer-vision-mlops/data/runs/detect/train7/weights/best.pt...
# Ultralytics 8.4.10 🚀 Python-3.12.3 torch-2.10.0+cu128 CPU (Intel Core i7-3517U 1.90GHz)
# [W204 12:16:50.335450021 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 12:16:50.352474246 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 12:16:50.357577513 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 12:16:50.359365344 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 12:16:50.361429923 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 12:16:50.363181312 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 12:16:50.365226347 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 12:16:50.371111464 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 12:16:50.373572796 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 12:16:50.384943040 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 12:16:50.387863662 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 12:16:50.390882725 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 12:16:50.392544948 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 12:16:50.396505461 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 12:16:50.399643327 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 12:16:50.401371554 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 12:16:50.408391541 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 12:16:50.410088227 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 12:16:50.413715771 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 12:16:50.418850102 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 12:16:50.425685068 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 12:16:50.431996059 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 12:16:50.433724912 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 12:16:50.435091149 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 12:16:50.436753653 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 12:16:50.438085356 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 12:16:50.440742374 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 12:16:50.446780707 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 12:16:50.453718715 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 12:16:50.462112536 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 12:16:50.471538712 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 12:16:50.476610738 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 12:16:50.483852270 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 12:16:50.496978888 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 12:16:50.508765505 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 12:16:50.513548645 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 12:16:50.521299664 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 12:16:50.525247845 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 12:16:50.532857144 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 12:16:50.538071631 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 12:16:50.541906878 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 12:16:50.563861094 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 12:16:50.570263126 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 12:16:50.581689666 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 12:16:50.595755144 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 12:16:50.601632448 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 12:16:50.615306224 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 12:16:50.639738621 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 12:16:50.680312716 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 12:16:50.690855742 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 12:16:50.698574984 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 12:16:50.712408029 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 12:16:50.731472699 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 12:16:50.742121373 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 12:16:50.755607175 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# Model summary (fused): 73 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
# [W204 12:16:50.782922745 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 12:16:50.801635181 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 12:16:50.818063094 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 12:16:50.830522560 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 12:16:50.843767911 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 12:16:50.853666747 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 12:16:50.865612802 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 12:16:50.891632178 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W204 12:16:50.931569088 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 14.5s/it 58.2s23.6s
#                    all         31        511       0.69      0.675      0.677      0.374
# Speed: 40.4ms preprocess, 1683.4ms inference, 0.0ms loss, 33.9ms postprocess per image
# Results saved to /home/user/end-to-end-computer-vision-mlops/data/runs/detect/train7
# 🏃 View run YOLOv8-Nano at: http://127.0.0.1:5000/#/experiments/4/runs/045774a3fc5d4fbdbb21f97892ef29fe
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/4
# MLflow: results logged to http://127.0.0.1:5000
# MLflow: disable with 'yolo settings mlflow=False'

# %%
# Raw PyTorch model (for research)
mlflow.pytorch.log_model(model.model, "torch-model")

# Full YOLO model (for inference)
model.save("yolov8_model.pt")
mlflow.log_artifact("yolov8_model.pt")
# Out:
# 2026/02/04 12:19:14 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/02/04 12:19:18 WARNING mlflow.pytorch: Saving pytorch model by Pickle or CloudPickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization.The recommended safe alternative is to set 'export_model' to True to save the pytorch model using the safe graph model format.
